# %% [markdown]
# <a href="https://colab.research.google.com/github/Malaika944/Regularization/blob/main/Lasso_sparsity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
data = load_diabetes()

# %%
x= data.data
y = data.target

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=2 ,test_size=0.2)

# %%
#Linear Regression
lr = LinearRegression()
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
print("R2 Score is:",r2_score(y_test,y_pred))
# Out:
# R2 Score is: 0.4399338661568968

# %%
#Ridge Regression
lr = Ridge(alpha=0.1)
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
print("R2 Score is:",r2_score(y_test,y_pred))
# Out:
# R2 Score is: 0.45199494197195456
